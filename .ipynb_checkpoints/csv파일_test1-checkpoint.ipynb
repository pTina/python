# %% [markdown]
# - 결측값: 누락된 데이터
# - .dtypes => 데이터 타입이 여러개 있는 경우 사용한다.
# - .dtype => 시리즈처럼 데이터 타입이 1개인 경우만 사용 가능

# %%
import pandas as pd

# %%
df1 = pd.read_csv('train_transactions.csv',encoding='cp949')

# %%
# .head() => 상위 5개 항목 추출
# .head(n) => 상위 n개 항목 추출
df1.head()
# Out:
#    custid           sales_date  sales_time str_nm         goodcd brd_nm  \
# 0      18  2000-12-09 00:00:00        1523    신촌점  2116052008000   크리니크
# 1      18  2000-12-09 00:00:00        1730    신촌점  4220830013076   BCBG
# 2      18  2000-12-09 00:00:00        1712    신촌점  2116052008000   크리니크
# 3      18  2000-12-09 00:00:00        1710    신촌점  2116052008000   크리니크
# 4      18  2001-02-03 00:00:00        1822    신촌점  2116052008000   크리니크
#
#   corner_nm  pc_nm part_nm team_nm buyer_nm  import_flg  tot_amt  dis_amt  \
# 0   수입종합화장품    화장품    패션잡화   잡화가용팀      화장품           1    43000     2150
# 1   칼라드래디셔널  타운란제리   여성캐주얼   의류패션팀  엘레강스캐주얼           0   148000        0
# 2   수입종합화장품    화장품    패션잡화   잡화가용팀      화장품           1    43000     4300
# 3   수입종합화장품    화장품    패션잡화   잡화가용팀      화장품           1   -43000    -2150
# 4   수입종합화장품    화장품    패션잡화   잡화가용팀      화장품           1    19000     1900
#
#    net_amt  inst_mon
# 0    40850         1
# 1   148000         3
# ...

# %%
# .tail() => 하위 5개 항목추출
# .tail(n) => 하위 n개 항목 추출
df1.tail()
# Out:
#         custid           sales_date  sales_time str_nm         goodcd brd_nm  \
# 172687   49993  2001-03-20 00:00:00        1800     본점  2139141008000     랑콤
# 172688   49993  2001-04-08 00:00:00        1730     본점  4400101020010   게스키즈
# 172689   49993  2001-03-20 00:00:00        1800     본점  2700000000000     식품
# 172690   49993  2001-04-03 00:00:00        1410     본점  2700000000000     식품
# 172691   49993  2001-04-21 00:00:00        1140     본점  2700000000000     식품
#
#        corner_nm pc_nm    part_nm team_nm buyer_nm  import_flg  tot_amt  \
# 172687   수입종합화장품   화장품       잡화파트   잡화가용팀      화장품           0    95000
# 172688        아동   아동복  케주얼,구두,아동   의류패션팀     유아동복           0    53910
# 172689        야채   농산물      생식품파트     식품팀     일반식품           0    33270
# 172690        야채   농산물      생식품파트     식품팀     일반식품           0   171642
# 172691      일용잡화  생활용품      공산품파트     식품팀     일반식품           0    88257
#
#         dis_amt  net_amt  inst_mon
# ...

# %%
df1.dtypes
# Out:
# custid         int64
# sales_date    object
# sales_time     int64
# str_nm        object
# goodcd         int64
# brd_nm        object
# corner_nm     object
# pc_nm         object
# part_nm       object
# team_nm       object
# buyer_nm      object
# import_flg     int64
# tot_amt        int64
# dis_amt        int64
# net_amt        int64
# inst_mon       int64
# dtype: object

# %%
# 테이블의 기초정보 확인하기
# 전체 행의 개수 => 172691 + 1(index가 0부터 시작하므로)
# 열의 개수 => int64(8), object(8) => int(8개), object(8개)
# 데이터이탑은 보통: int, object(str이랑 같음), float, boolean, ...

# Non-Null Count => 결측값 개수(누락데이터 개수)
# => non-null : 결측값이 없다.
# ex) 1000 non-null => 결측값 = 전체행개수 - 1000개
# 결측값이 많을수록 좋지않은 데이터다.

df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 172692 entries, 0 to 172691
# Data columns (total 16 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   custid      172692 non-null  int64
#  1   sales_date  172692 non-null  object
#  2   sales_time  172692 non-null  int64
#  3   str_nm      172692 non-null  object
#  4   goodcd      172692 non-null  int64
#  5   brd_nm      172692 non-null  object
#  6   corner_nm   172692 non-null  object
#  7   pc_nm       172692 non-null  object
#  8   part_nm     172692 non-null  object
#  9   team_nm     172692 non-null  object
#  10  buyer_nm    172692 non-null  object
#  11  import_flg  172692 non-null  int64
#  12  tot_amt     172692 non-null  int64
#  13  dis_amt     172692 non-null  int64
#  14  net_amt     172692 non-null  int64
#  15  inst_mon    172692 non-null  int64
# dtypes: int64(8), object(8)
# memory usage: 21.1+ MB

# %%
# 테이블안에서 buyer_nm이 '화장품'인것만 추출해라.
df1[ df1['buyer_nm']=='화장품' ]
# Out:
#         custid           sales_date  sales_time str_nm         goodcd  \
# 0           18  2000-12-09 00:00:00        1523    신촌점  2116052008000
# 2           18  2000-12-09 00:00:00        1712    신촌점  2116052008000
# 3           18  2000-12-09 00:00:00        1710    신촌점  2116052008000
# 4           18  2001-02-03 00:00:00        1822    신촌점  2116052008000
# 11          18  2001-03-24 00:00:00        1632    신촌점  4132320008000
# ...        ...                  ...         ...    ...            ...
# 172665   49993  2000-05-04 00:00:00        1700     본점  4100830008000
# 172668   49993  2000-06-30 00:00:00        1800     본점  4124181008000
# 172672   49993  2000-08-06 00:00:00        1450     본점  4139660008000
# 172674   49993  2000-08-06 00:00:00        1440     본점  4100830008000
# 172687   49993  2001-03-20 00:00:00        1800     본점  2139141008000
#
#          brd_nm corner_nm pc_nm part_nm team_nm buyer_nm  import_flg  tot_amt  \
# ...

# %%
# 신촌점에서 팔린 화장품 데이터만 가져와라
df1[ (df1['buyer_nm']=='화장품') & (df1['str_nm']=='신촌점')]
# Out:
#         custid           sales_date  sales_time str_nm         goodcd brd_nm  \
# 0           18  2000-12-09 00:00:00        1523    신촌점  2116052008000   크리니크
# 2           18  2000-12-09 00:00:00        1712    신촌점  2116052008000   크리니크
# 3           18  2000-12-09 00:00:00        1710    신촌점  2116052008000   크리니크
# 4           18  2001-02-03 00:00:00        1822    신촌점  2116052008000   크리니크
# 11          18  2001-03-24 00:00:00        1632    신촌점  4132320008000    아베다
# ...        ...                  ...         ...    ...            ...    ...
# 171979   49847  2000-09-02 00:00:00        1803    신촌점  2116050008000  에스티로더
# 171980   49847  2001-01-02 00:00:00        1223    신촌점  2116050008000  에스티로더
# 172255   49910  2000-10-12 00:00:00        1343    신촌점  2116050008000  에스티로더
# 172610   49957  2000-05-01 00:00:00        1323    신촌점  2116050008000  에스티로더
# 172649   49975  2000-06-21 00:00:00        1823    신촌점  4124180008000   시세이도
#
# ...

# %%
# 신촌점에 있는 화장품 중에서 판매액의 평균치 가져와라.
# df1[ (df1['buyer_nm']=='화장품') & (df1['str_nm']=='신촌점')] => 신촌점의 화장품 데이터 추출
# ['tot_amt'] => tot_amt의 열을 가져와 .mean()로 평균값 구한것
df1[ (df1['buyer_nm']=='화장품') & (df1['str_nm']=='신촌점')]['tot_amt'].mean()
# Out:
# 76049.08318857364

# %%
# 신촌점 화장품의 tot_amt를 시리즈로 가져옴
df1[(df1['buyer_nm']=='화장품') & (df1['str_nm']=='신촌점')]['tot_amt']
# Out:
# 0          43000
# 2          43000
# 3         -43000
# 4          19000
# 11         42000
#            ...
# 171979    170000
# 171980    160000
# 172255    125000
# 172610     53000
# 172649     35000
# Name: tot_amt, Length: 5181, dtype: int64

# %%
# 신촌점 화장품의 tot_amt를 데이터 프레임으로 가져옴
# 데이터프레임으로 바꿀라면 pd.DataFrame()으로 묶으면 됨
pd.DataFrame(df1[(df1['buyer_nm']=='화장품') & (df1['str_nm']=='신촌점')]['tot_amt'])
# Out:
#         tot_amt
# 0         43000
# 2         43000
# 3        -43000
# 4         19000
# 11        42000
# ...         ...
# 171979   170000
# 171980   160000
# 172255   125000
# 172610    53000
# 172649    35000
#
# [5181 rows x 1 columns]

# %%
# 백화점 데이터에서 지점이 몇 개가 있을까용?

# 1. str_nm의 열을 가져온다.
sh = df1['str_nm']
sh
# Out:
# 0         신촌점
# 1         신촌점
# 2         신촌점
# 3         신촌점
# 4         신촌점
#          ...
# 172687     본점
# 172688     본점
# 172689     본점
# 172690     본점
# 172691     본점
# Name: str_nm, Length: 172692, dtype: object

# %%
# 2. 유니크값을 찾는다.
sh.unique()
# Out:
# array(['신촌점', '무역점', '본점', '천호점'], dtype=object)

# %%
# 3. 유니크 값의 개수를 찾는다.
sh.nunique()
# Out:
# 4

# %%
# 본점의 part_nm별 총 판매액을 구해라.
# 1. 본점인 애들만 추출한다.
sh2 = df1[df1['str_nm']=='본점']
sh2
# Out:
#         custid           sales_date  sales_time str_nm         goodcd brd_nm  \
# 65          26  2000-11-18 00:00:00        1620     본점  4227690011200  엘르스포츠
# 180        102  2000-08-20 00:00:00        1740     본점  4109350003200     탠디
# 181        102  2000-12-16 00:00:00        1730     본점  4104840008000     샤넬
# 244        148  2000-05-21 00:00:00        1610     본점  4400510025000     울시
# 303        175  2000-05-07 00:00:00        1750     본점  4118860003000   무크구두
# ...        ...                  ...         ...    ...            ...    ...
# 172687   49993  2001-03-20 00:00:00        1800     본점  2139141008000     랑콤
# 172688   49993  2001-04-08 00:00:00        1730     본점  4400101020010   게스키즈
# 172689   49993  2001-03-20 00:00:00        1800     본점  2700000000000     식품
# 172690   49993  2001-04-03 00:00:00        1410     본점  2700000000000     식품
# 172691   49993  2001-04-21 00:00:00        1140     본점  2700000000000     식품
#
# ...

# %%
# 2. part_nm 가져오기
array = sh2['part_nm'].unique()
array
# Out:
# array(['케주얼,구두,아동', '잡화파트', '남성정장스포츠', '여성의류파트', '공산품파트', '가정용품파트',
#        '로얄부띠끄', '생식품파트'], dtype=object)

# %%
sh2[sh2['part_nm']=='케주얼,구두,아동']['tot_amt'].sum()
# Out:
# 929072380

# %%
# 3. 각 카테고리별 총합 구하기
for i in array:
    result = sh2[sh2['part_nm']== i]['tot_amt'].sum()
    print('{}: {}원'.format(i,result))
# Out:
# 케주얼,구두,아동: 929072380원
# 잡화파트: 1472441970원
# 남성정장스포츠: 697799160원
# 여성의류파트: 825761606원
# 공산품파트: 272055253원
# 가정용품파트: 359471540원
# 로얄부띠끄: 618891400원
# 생식품파트: 279299691원

# %%
# 간단하게 하는 방법 "그룹핑"
# 본점인 데이터 추출.prt_nm별로그룹핑.tot_amt에대하여.총합.표로보여라
# .reset_index(name="index_name") => index에 들어갈 이름 지정
# .rename(columns={'컬럼이름'='바꿀이름'})
sh2.groupby('part_nm').tot_amt.sum().reset_index(name="총판매액").rename(columns = {'part_nm':'파트'})
# Out:
#           파트        총판매액
# 0     가정용품파트   359471540
# 1      공산품파트   272055253
# 2    남성정장스포츠   697799160
# 3      로얄부띠끄   618891400
# 4      생식품파트   279299691
# 5     여성의류파트   825761606
# 6       잡화파트  1472441970
# 7  케주얼,구두,아동   929072380
