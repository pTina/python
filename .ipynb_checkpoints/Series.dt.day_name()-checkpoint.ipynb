# %%
import pandas as pd
# import datetime as dt
# import numpy as np

df1 = pd.read_csv('train_transactions.csv',encoding='cp949')
df1
# Out:
#         custid           sales_date  sales_time str_nm         goodcd brd_nm  \
# 0           18  2000-12-09 00:00:00        1523    신촌점  2116052008000   크리니크
# 1           18  2000-12-09 00:00:00        1730    신촌점  4220830013076   BCBG
# 2           18  2000-12-09 00:00:00        1712    신촌점  2116052008000   크리니크
# 3           18  2000-12-09 00:00:00        1710    신촌점  2116052008000   크리니크
# 4           18  2001-02-03 00:00:00        1822    신촌점  2116052008000   크리니크
# ...        ...                  ...         ...    ...            ...    ...
# 172687   49993  2001-03-20 00:00:00        1800     본점  2139141008000     랑콤
# 172688   49993  2001-04-08 00:00:00        1730     본점  4400101020010   게스키즈
# 172689   49993  2001-03-20 00:00:00        1800     본점  2700000000000     식품
# 172690   49993  2001-04-03 00:00:00        1410     본점  2700000000000     식품
# 172691   49993  2001-04-21 00:00:00        1140     본점  2700000000000     식품
#
# ...

# %%
df1.sales_date.dtype
# Out:
# dtype('O')

# %%
df1['sales_date'] = pd.to_datetime(df1['sales_date'])
df1.sales_date.dtype
# Out:
# dtype('<M8[ns]')

# %%
df1.sales_date
# Out:
# 0        2000-12-09
# 1        2000-12-09
# 2        2000-12-09
# 3        2000-12-09
# 4        2001-02-03
#             ...
# 172687   2001-03-20
# 172688   2001-04-08
# 172689   2001-03-20
# 172690   2001-04-03
# 172691   2001-04-21
# Name: sales_date, Length: 172692, dtype: datetime64[ns]

# %%
df1['sales_date'] = df1['sales_date'].dt.day_name()
df1.sales_date
# Out:
# 0         Saturday
# 1         Saturday
# 2         Saturday
# 3         Saturday
# 4         Saturday
#             ...
# 172687     Tuesday
# 172688      Sunday
# 172689     Tuesday
# 172690     Tuesday
# 172691    Saturday
# Name: sales_date, Length: 172692, dtype: object

# %%
pd.DataFrame(df1.groupby(['str_nm','sales_date','part_nm']).tot_amt.sum())
# Out:
#                               tot_amt
# str_nm sales_date part_nm
# 무역점    Friday     가정용품       81843260
#                   골프/유니캐쥬얼   77968360
#                   공산품        35149490
#                   남성의류       44483500
#                   명품잡화      234490970
# ...                               ...
# 천호점    Wednesday  여성정장       30494900
#                   여성캐쥬얼      29605400
#                   영라이브       23583870
#                   영어덜트캐쥬얼    32653300
#                   잡화         62022220
#
# [287 rows x 1 columns]
